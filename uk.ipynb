# %%
import pandas as pd

# %%
df = pd.read_csv('student_uk_visa_dataset.csv')
df.head()
# Out:
#     gpa  ielts_score visited_uk_before has_scholarship_offer  \
# 0  3.09          6.8                No                    No
# 1  2.33          7.0           Unknown                   Yes
# 2  3.19          5.5               Yes                   Yes
# 3  3.31          5.5                No                   Yes
# 4  3.28          7.5                No                    No
#
#   financial_documents_ready        age country_of_origin field_of_study  \
# 0                        No  21.916850             Sudan            Law
# 1                        No  30.737632             Kenya       Medicine
# 2                        No  21.413334             China             IT
# 3                       Yes  12.875225             Egypt        Science
# 4                       Yes  27.054540           Nigeria        Science
#
#    university_rank_applied has_recommendation_letters visa_approved
# 0                       68                        Yes           Yes
# ...

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gpa                         950 non-null    float64
#  1   ielts_score                 962 non-null    float64
#  2   visited_uk_before           1000 non-null   object
#  3   has_scholarship_offer       1000 non-null   object
#  4   financial_documents_ready   1000 non-null   object
#  5   age                         970 non-null    float64
#  6   country_of_origin           1000 non-null   object
#  7   field_of_study              1000 non-null   object
#  8   university_rank_applied     1000 non-null   int64
#  9   has_recommendation_letters  1000 non-null   object
#  10  visa_approved               1000 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB
# ...

# %%
df.isna().sum()
# Out:
# gpa                           50
# ielts_score                   38
# visited_uk_before              0
# has_scholarship_offer          0
# financial_documents_ready      0
# age                           30
# country_of_origin              0
# field_of_study                 0
# university_rank_applied        0
# has_recommendation_letters     0
# visa_approved                  0
# dtype: int64

# %%
import numpy as np

df.loc[df['ielts_score'] > 9, 'ielts_score'] = np.nan

# %%
df.describe()
# Out:
#               gpa  ielts_score         age  university_rank_applied
# count  950.000000   948.000000  970.000000              1000.000000
# mean     3.046874     6.448312   24.975796                50.430000
# std      0.528545     1.034682    4.854206                29.092292
# min      0.500000     2.000000   12.135771                -5.000000
# 25%      2.710000     5.800000   22.017813                26.000000
# 50%      3.040000     6.450000   24.922808                49.000000
# 75%      3.380000     7.200000   27.651945                76.000000
# max      4.500000     8.900000   60.000000               105.000000

# %%
df['ielts_score'].fillna(df['ielts_score'].median(), inplace=True)
# Out:
# C:\Users\Mohammed Abkam\AppData\Local\Temp\ipykernel_20000\2389346171.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ielts_score'].fillna(df['ielts_score'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# gpa                           50
# ielts_score                    0
# visited_uk_before              0
# has_scholarship_offer          0
# financial_documents_ready      0
# age                           30
# country_of_origin              0
# field_of_study                 0
# university_rank_applied        0
# has_recommendation_letters     0
# visa_approved                  0
# dtype: int64

# %%
df['age'].describe()
# Out:
# count    970.000000
# mean      24.975796
# std        4.854206
# min       12.135771
# 25%       22.017813
# 50%       24.922808
# 75%       27.651945
# max       60.000000
# Name: age, dtype: float64

# %%
df[df['age'] > 27]
# Out:
#       gpa  ielts_score visited_uk_before has_scholarship_offer  \
# 1    2.33         7.00           Unknown                   Yes
# 4    3.28         7.50                No                    No
# 14   2.46         5.40                No                    No
# 15   3.53         6.80                No                   Yes
# 22   3.05         6.45                No                    No
# ..    ...          ...               ...                   ...
# 981  3.37         7.10               Yes                    No
# 982  3.04         6.20               Yes                   Yes
# 984  2.88         6.45                No                   Yes
# 995  2.34         5.60               Yes                    No
# 998  2.79         5.60               Yes                   Yes
#
#     financial_documents_ready        age country_of_origin field_of_study  \
# 1                          No  30.737632             Kenya       Medicine
# ...

# %%
df['age'].fillna(df['age'].median(), inplace=True)
# Out:
# C:\Users\Mohammed Abkam\AppData\Local\Temp\ipykernel_20000\1654433547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(), inplace=True)

# %%
df.loc[df['age'] > 40, 'age'] = df['age'].median()

# %%
df.isnull().sum()
# Out:
# gpa                           50
# ielts_score                    0
# visited_uk_before              0
# has_scholarship_offer          0
# financial_documents_ready      0
# age                            0
# country_of_origin              0
# field_of_study                 0
# university_rank_applied        0
# has_recommendation_letters     0
# visa_approved                  0
# dtype: int64

# %%
df['country_of_origin'].unique()
# Out:
# array(['Sudan', 'Kenya', 'China', 'Egypt', 'Nigeria', 'Unknown', 'Ghana',
#        'India', 'Pakistan'], dtype=object)

# %%
df['country_of_origin'].mode()
# Out:
# 0    India
# Name: country_of_origin, dtype: object

# %%
continent_map = {
    'Sudan': 'Africa',
    'Kenya': 'Africa',
    'Nigeria': 'Africa',
    'Ghana': 'Africa',
    'Egypt': 'Africa',
    'India': 'Asia',
    'Pakistan': 'Asia',
    'China': 'Asia',
    'Unknown': 'Unknown'
}
df['continent'] = df['country_of_origin'].map(continent_map)

# %%
df1 = df.copy()

# %%
df.head()
# Out:
#     gpa  ielts_score visited_uk_before has_scholarship_offer  \
# 0  3.09          6.8                No                    No
# 1  2.33          7.0           Unknown                   Yes
# 2  3.19          5.5               Yes                   Yes
# 3  3.31          5.5                No                   Yes
# 4  3.28          7.5                No                    No
#
#   financial_documents_ready        age country_of_origin field_of_study  \
# 0                        No  21.916850             Sudan            Law
# 1                        No  30.737632             Kenya       Medicine
# 2                        No  21.413334             China             IT
# 3                       Yes  12.875225             Egypt        Science
# 4                       Yes  27.054540           Nigeria        Science
#
#    university_rank_applied has_recommendation_letters visa_approved continent
# 0                       68                        Yes           Yes    Africa
# ...

# %%
df['continent'].value_counts()
# Out:
# continent
# Africa     549
# Asia       352
# Unknown     99
# Name: count, dtype: int64

# %%
mode_value = df[df['continent'] != 'Unknown']['continent'].mode()[0]
df['continent'] = df['continent'].replace('Unknown', mode_value)
df['continent'].value_counts()
# Out:
# continent
# Africa    648
# Asia      352
# Name: count, dtype: int64

# %%
df['field_of_study'].unique()
# Out:
# array(['Law', 'Medicine', 'IT', 'Science', 'Arts', 'Education',
#        'Engineering', 'Business'], dtype=object)

# %%
df['financial_documents_ready'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['has_recommendation_letters'].unique()
df['has_recommendation_letters'].value_counts()
# Out:
# has_recommendation_letters
# Yes        604
# No         311
# Unknown     85
# Name: count, dtype: int64

# %%
mode_v = df[df['has_recommendation_letters'] != 'Unknown']['has_recommendation_letters'].mode()[0]
df['has_recommendation_letters'] = df['has_recommendation_letters'].replace('Unknown', mode_v)
df['has_recommendation_letters'].value_counts()
# Out:
# has_recommendation_letters
# Yes    689
# No     311
# Name: count, dtype: int64

# %%
df['has_scholarship_offer'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['university_rank_applied'].unique()
# Out:
# array([ 68,  59,  91,  10,  13,   2,  90,  15,  46,  57,  22,  89,  79,
#         77,   8,  21,  85,  97,  45,  40,  30,  62,  73,  35,  82,  42,
#          5,  27,  70,  -5,  32,  18,  78,  26,  53,  44,  28,  39,  11,
#         20,  69,  99,  24,  17,  98,  12,  16,   4,  34,  92,  75,  31,
#         25,  74,  65,  36,   6,  66,  67,  72,  95,  48,  83, 105,  94,
#         63,  19,  64,  71,  50,  41,   7,   9,  49,  76,  56,  29,  60,
#         84,  23,  80,  51, 100,  81,  86,   1,  58,  52,  37,  87,  55,
#         38,  93,  33,   3,  54,  88,  47,  96,  14,  43,  61])

# %%
df['university_rank_applied'].describe()
# Out:
# count    1000.000000
# mean       50.430000
# std        29.092292
# min        -5.000000
# 25%        26.000000
# 50%        49.000000
# 75%        76.000000
# max       105.000000
# Name: university_rank_applied, dtype: float64

# %%
df.loc[(df['university_rank_applied'] < 0), 'university_rank_applied'] = df['university_rank_applied'].median()

# %%
df.loc[(df['university_rank_applied'] > 100), 'university_rank_applied'] = df['university_rank_applied'].median()

# %%
df['university_rank_applied'].unique()
# Out:
# array([ 68,  59,  91,  10,  13,   2,  90,  15,  46,  57,  22,  89,  79,
#         77,   8,  21,  85,  97,  45,  40,  30,  62,  73,  35,  82,  42,
#          5,  27,  70,  49,  32,  18,  78,  26,  53,  44,  28,  39,  11,
#         20,  69,  99,  24,  17,  98,  12,  16,   4,  34,  92,  75,  31,
#         25,  74,  65,  36,   6,  66,  67,  72,  95,  48,  83,  94,  63,
#         19,  64,  71,  50,  41,   7,   9,  76,  56,  29,  60,  84,  23,
#         80,  51, 100,  81,  86,   1,  58,  52,  37,  87,  55,  38,  93,
#         33,   3,  54,  88,  47,  96,  14,  43,  61])

# %%
df['visited_uk_before'].unique()
# Out:
# array(['No', 'Unknown', 'Yes'], dtype=object)

# %%
df['visited_uk_before'].value_counts()
# Out:
# visited_uk_before
# No         580
# Yes        307
# Unknown    113
# Name: count, dtype: int64

# %%
df.groupby('visited_uk_before')['continent'].value_counts()
# Out:
# visited_uk_before  continent
# No                 Africa       375
#                    Asia         205
# Unknown            Africa        74
#                    Asia          39
# Yes                Africa       199
#                    Asia         108
# Name: count, dtype: int64

# %%
import numpy as np

# معالجة Unknown في أفريقيا
mask_africa = (df['visited_uk_before'] == 'Unknown') & (df['continent'] == 'Africa')
df.loc[mask_africa, 'visited_uk_before'] = np.random.choice(['Yes', 'No'], size=mask_africa.sum(), p=[0.35, 0.65])

# معالجة Unknown في آسيا
mask_asia = (df['visited_uk_before'] == 'Unknown') & (df['continent'] == 'Asia')
df.loc[mask_asia, 'visited_uk_before'] = np.random.choice(['Yes', 'No'], size=mask_asia.sum(), p=[0.35, 0.65])

# %%
print(df.groupby(['visited_uk_before', 'continent']).size())
# Out:
# visited_uk_before  continent
# No                 Africa       430
#                    Asia         234
# Yes                Africa       218
#                    Asia         118
# dtype: int64

# %%
df['visa_approved'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['age'], kde=True, bins=30)
plt.title('Distribution of Your Numeric Column')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gpa                         950 non-null    float64
#  1   ielts_score                 1000 non-null   float64
#  2   visited_uk_before           1000 non-null   object
#  3   has_scholarship_offer       1000 non-null   object
#  4   financial_documents_ready   1000 non-null   object
#  5   age                         1000 non-null   float64
#  6   country_of_origin           1000 non-null   object
#  7   field_of_study              1000 non-null   object
#  8   university_rank_applied     1000 non-null   int64
#  9   has_recommendation_letters  1000 non-null   object
#  10  visa_approved               1000 non-null   object
#  11  continent                   1000 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 93.9+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['university_rank_applied'], kde=True, bins=30)
plt.title('Distribution of Your Numeric Column')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(df['ielts_score'], kde=True, bins=30)
plt.title('Distribution of Your Numeric Column')
plt.xlabel('Value')
plt.ylabel('Count')
plt.show()

# %%
df['gpa'].fillna(df['gpa'].median(), inplace=True)
# Out:
# C:\Users\Mohammed Abkam\AppData\Local\Temp\ipykernel_20000\26362644.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gpa'].fillna(df['gpa'].median(), inplace=True)

# %%
df.drop(columns=['country_of_origin'], inplace=True, errors='ignore')

# %%
df3 = df.copy()

# %%
df.head()
# Out:
#     gpa  ielts_score visited_uk_before has_scholarship_offer  \
# 0  3.09          6.8                No                    No
# 1  2.33          7.0                No                   Yes
# 2  3.19          5.5               Yes                   Yes
# 3  3.31          5.5                No                   Yes
# 4  3.28          7.5                No                    No
#
#   financial_documents_ready        age field_of_study  \
# 0                        No  21.916850            Law
# 1                        No  30.737632       Medicine
# 2                        No  21.413334             IT
# 3                       Yes  12.875225        Science
# 4                       Yes  27.054540        Science
#
#    university_rank_applied has_recommendation_letters visa_approved continent
# 0                       68                        Yes           Yes    Africa
# 1                       59                        Yes            No    Africa
# ...

# %%
c = pd.get_dummies(df['continent'], prefix='continent', drop_first=True)

# %%
df = pd.concat([df.drop('continent', axis=1), c], axis=1)

# %%
df.head()
# Out:
#     gpa  ielts_score visited_uk_before has_scholarship_offer  \
# 0  3.09          6.8                No                    No
# 1  2.33          7.0                No                   Yes
# 2  3.19          5.5               Yes                   Yes
# 3  3.31          5.5                No                   Yes
# 4  3.28          7.5                No                    No
#
#   financial_documents_ready        age field_of_study  \
# 0                        No  21.916850            Law
# 1                        No  30.737632       Medicine
# 2                        No  21.413334             IT
# 3                       Yes  12.875225        Science
# 4                       Yes  27.054540        Science
#
#    university_rank_applied has_recommendation_letters visa_approved  \
# 0                       68                        Yes           Yes
# 1                       59                        Yes            No
# ...

# %%
df7 = df.copy()
df7['continent_Africa'] = (df7['continent_Asia'] == False).astype(int)

# %%
df7.head()
# Out:
#     gpa  ielts_score visited_uk_before has_scholarship_offer  \
# 0  3.09          6.8                No                    No
# 1  2.33          7.0                No                   Yes
# 2  3.19          5.5               Yes                   Yes
# 3  3.31          5.5                No                   Yes
# 4  3.28          7.5                No                    No
#
#   financial_documents_ready        age field_of_study  \
# 0                        No  21.916850            Law
# 1                        No  30.737632       Medicine
# 2                        No  21.413334             IT
# 3                       Yes  12.875225        Science
# 4                       Yes  27.054540        Science
#
#    university_rank_applied has_recommendation_letters visa_approved  \
# 0                       68                        Yes           Yes
# 1                       59                        Yes            No
# ...

# %%
df = df7.copy()
def yes_no_to_binary(column):
    return column.map({'Yes': 1, 'No': 0})
df['visited_uk_before'] = yes_no_to_binary(df['visited_uk_before'])

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before has_scholarship_offer  \
# 0  3.09          6.8                  0                    No
# 1  2.33          7.0                  0                   Yes
# 2  3.19          5.5                  1                   Yes
# 3  3.31          5.5                  0                   Yes
# 4  3.28          7.5                  0                    No
#
#   financial_documents_ready        age field_of_study  \
# 0                        No  21.916850            Law
# 1                        No  30.737632       Medicine
# 2                        No  21.413334             IT
# 3                       Yes  12.875225        Science
# 4                       Yes  27.054540        Science
#
#    university_rank_applied has_recommendation_letters visa_approved  \
# 0                       68                        Yes           Yes
# 1                       59                        Yes            No
# ...

# %%
df['has_scholarship_offer'] = yes_no_to_binary(df['has_scholarship_offer'])

# %%
df['financial_documents_ready'] = yes_no_to_binary(df['financial_documents_ready'])

# %%
df10 = df.copy()

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age field_of_study  \
# 0                          0  21.916850            Law
# 1                          0  30.737632       Medicine
# 2                          0  21.413334             IT
# 3                          1  12.875225        Science
# 4                          1  27.054540        Science
#
#    university_rank_applied has_recommendation_letters visa_approved  \
# 0                       68                        Yes           Yes
# 1                       59                        Yes            No
# ...

# %%
df['has_recommendation_letters'] = yes_no_to_binary(df['has_recommendation_letters'])

# %%
df['visa_approved'] = yes_no_to_binary(df['visa_approved'])

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age field_of_study  \
# 0                          0  21.916850            Law
# 1                          0  30.737632       Medicine
# 2                          0  21.413334             IT
# 3                          1  12.875225        Science
# 4                          1  27.054540        Science
#
#    university_rank_applied  has_recommendation_letters  visa_approved  \
# 0                       68                           1              1
# 1                       59                           1              0
# ...

# %%
df11 = df.copy()
df11['continent_Asia'] = (df11['continent_Asia'] == True).astype(int)

# %%
df11.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age field_of_study  \
# 0                          0  21.916850            Law
# 1                          0  30.737632       Medicine
# 2                          0  21.413334             IT
# 3                          1  12.875225        Science
# 4                          1  27.054540        Science
#
#    university_rank_applied  has_recommendation_letters  visa_approved  \
# 0                       68                           1              1
# 1                       59                           1              0
# ...

# %%
df = df11.copy()

# %%
df['field_of_study'].value_counts()
# Out:
# field_of_study
# Law            147
# Medicine       129
# Education      129
# Engineering    125
# IT             123
# Business       121
# Science        120
# Arts           106
# Name: count, dtype: int64

# %%
field_map = {
    'Law': 'Social Studies',
    'Education': 'Social Studies',
    'Arts': 'Social Studies',
    'Medicine': 'Health',
    'Engineering': 'STEM',
    'IT': 'STEM',
    'Science': 'STEM',
    'Business': 'Business'
}

df['field_grouped'] = df['field_of_study'].map(field_map)

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age field_of_study  \
# 0                          0  21.916850            Law
# 1                          0  30.737632       Medicine
# 2                          0  21.413334             IT
# 3                          1  12.875225        Science
# 4                          1  27.054540        Science
#
#    university_rank_applied  has_recommendation_letters  visa_approved  \
# 0                       68                           1              1
# 1                       59                           1              0
# ...

# %%
field_dummies = pd.get_dummies(df['field_grouped'], prefix='field', drop_first=True)
df = pd.concat([df, field_dummies], axis=1)

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age field_of_study  \
# 0                          0  21.916850            Law
# 1                          0  30.737632       Medicine
# 2                          0  21.413334             IT
# 3                          1  12.875225        Science
# 4                          1  27.054540        Science
#
#    university_rank_applied  has_recommendation_letters  visa_approved  \
# 0                       68                           1              1
# 1                       59                           1              0
# ...

# %%
df13 = df.copy()

# %%
df.drop(['field_grouped', 'field_of_study'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age  university_rank_applied  \
# 0                          0  21.916850                       68
# 1                          0  30.737632                       59
# 2                          0  21.413334                       91
# 3                          1  12.875225                       10
# 4                          1  27.054540                       13
#
#    has_recommendation_letters  visa_approved  continent_Asia  \
# 0                           1              1               0
# 1                           1              0               0
# ...

# %%
cols = ['field_Health', 'field_STEM', 'field_Social Studies']
df[cols] = df[cols].astype(int)

# %%
df.head()
# Out:
#     gpa  ielts_score  visited_uk_before  has_scholarship_offer  \
# 0  3.09          6.8                  0                      0
# 1  2.33          7.0                  0                      1
# 2  3.19          5.5                  1                      1
# 3  3.31          5.5                  0                      1
# 4  3.28          7.5                  0                      0
#
#    financial_documents_ready        age  university_rank_applied  \
# 0                          0  21.916850                       68
# 1                          0  30.737632                       59
# 2                          0  21.413334                       91
# 3                          1  12.875225                       10
# 4                          1  27.054540                       13
#
#    has_recommendation_letters  visa_approved  continent_Asia  \
# 0                           1              1               0
# 1                           1              0               0
# ...
